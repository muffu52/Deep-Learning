# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/mufdu/Documents/Deep-Learning/SemEval-Task10/data/sexist_data.csv")
df.head()
# Out:
#                   rewire_id  \
# 0  sexism2022_english-10142
# 1    sexism2022_english-760
# 2   sexism2022_english-1108
# 3  sexism2022_english-10099
# 4  sexism2022_english-10014
#
#                                                 text label_sexist  \
# 0  just the inside of your wallet: cash, bank car...       sexist
# 1  They get the initial chance because they are a...       sexist
# 2                    ugly chicks A pussy is a pussy.       sexist
# 3  fuck her off with a nine mm this is what you g...       sexist
# 4  How about I talk shit to an idiot like you? Ar...       sexist
#
#                              label_category  \
# 0                             2. derogation
# 1                             2. derogation
# 2                             2. derogation
# 3  1. threats, plans to harm and incitement
# 4                              3. animosity
#
#                                         label_vector
# 0  2.3 dehumanising attacks & overt sexual object...
# 1                            2.1 descriptive attacks
# 2  2.3 dehumanising attacks & overt sexual object...
# 3           1.2 incitement and encouragement of harm
# 4  3.1 casual use of gendered slurs, profanities,...

# %%
df['text']=df['text'].str.replace('[(#@&!?)]','')

df.head(5)
# Out:
# C:\Users\mufdu\AppData\Local\Temp\ipykernel_39432\862735610.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['text']=df['text'].str.replace('[(#@&!?)]','')
#                   rewire_id  \
# 0  sexism2022_english-10142
# 1    sexism2022_english-760
# 2   sexism2022_english-1108
# 3  sexism2022_english-10099
# 4  sexism2022_english-10014
#
#                                                 text label_sexist  \
# 0  just the inside of your wallet: cash, bank car...       sexist
# 1  They get the initial chance because they are a...       sexist
# 2                    ugly chicks A pussy is a pussy.       sexist
# 3  fuck her off with a nine mm this is what you g...       sexist
# 4  How about I talk shit to an idiot like you Are...       sexist
#
#                              label_category  \
# 0                             2. derogation
# 1                             2. derogation
# 2                             2. derogation
# 3  1. threats, plans to harm and incitement
# 4                              3. animosity
#
#                                         label_vector
# 0  2.3 dehumanising attacks & overt sexual object...
# 1                            2.1 descriptive attacks
# 2  2.3 dehumanising attacks & overt sexual object...
# 3           1.2 incitement and encouragement of harm
# 4  3.1 casual use of gendered slurs, profanities,...

# %%
import contractions

for index, row in df.iterrows():
  row['text'] = contractions.fix(row['text'])

# %%
df['text'] = df['text'].str.replace(r'[^\w\s]+', '')

df.head(5)
# Out:
# C:\Users\mufdu\AppData\Local\Temp\ipykernel_39432\2779130553.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['text'] = df['text'].str.replace(r'[^\w\s]+', '')
#                   rewire_id  \
# 0  sexism2022_english-10142
# 1    sexism2022_english-760
# 2   sexism2022_english-1108
# 3  sexism2022_english-10099
# 4  sexism2022_english-10014
#
#                                                 text label_sexist  \
# 0  just the inside of your wallet cash bank cards...       sexist
# 1  They get the initial chance because they are a...       sexist
# 2                     ugly chicks A pussy is a pussy       sexist
# 3  fuck her off with a nine mm this is what you g...       sexist
# 4  How about I talk shit to an idiot like you Are...       sexist
#
#                              label_category  \
# 0                             2. derogation
# 1                             2. derogation
# 2                             2. derogation
# 3  1. threats, plans to harm and incitement
# 4                              3. animosity
#
#                                         label_vector
# 0  2.3 dehumanising attacks & overt sexual object...
# 1                            2.1 descriptive attacks
# 2  2.3 dehumanising attacks & overt sexual object...
# 3           1.2 incitement and encouragement of harm
# 4  3.1 casual use of gendered slurs, profanities,...

# %%
df["text"] = df["text"].str.replace("URL","")
df["text"] = df["text"].str.replace("USER","")
df["text"] = df["text"].str.lower()
df.head(5)
# Out:
#                   rewire_id  \
# 0  sexism2022_english-10142
# 1    sexism2022_english-760
# 2   sexism2022_english-1108
# 3  sexism2022_english-10099
# 4  sexism2022_english-10014
#
#                                                 text label_sexist  \
# 0  just the inside of your wallet cash bank cards...       sexist
# 1  they get the initial chance because they are a...       sexist
# 2                     ugly chicks a pussy is a pussy       sexist
# 3  fuck her off with a nine mm this is what you g...       sexist
# 4  how about i talk shit to an idiot like you are...       sexist
#
#                              label_category  \
# 0                             2. derogation
# 1                             2. derogation
# 2                             2. derogation
# 3  1. threats, plans to harm and incitement
# 4                              3. animosity
#
#                                         label_vector
# 0  2.3 dehumanising attacks & overt sexual object...
# 1                            2.1 descriptive attacks
# 2  2.3 dehumanising attacks & overt sexual object...
# 3           1.2 incitement and encouragement of harm
# 4  3.1 casual use of gendered slurs, profanities,...

# %%
df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# Out:
#                      rewire_id  \
# 0     sexism2022_english-10142
# 1       sexism2022_english-760
# 2      sexism2022_english-1108
# 3     sexism2022_english-10099
# 4     sexism2022_english-10014
# ...                        ...
# 6743  sexism2022_english-19317
# 6744  sexism2022_english-15667
# 6745   sexism2022_english-1400
# 6746   sexism2022_english-4515
# 6747  sexism2022_english-14185
#
#                                                    text label_sexist  \
# 0     just the inside of your wallet cash bank cards...       sexist
# 1     they get the initial chance because they are a...       sexist
# 2                        ugly chicks a pussy is a pussy       sexist
# 3     fuck her off with a nine mm this is what you g...       sexist
# 4     how about i talk shit to an idiot like you are...       sexist
# ...                                                 ...          ...
# 6743  another democrat with signal glassesthere is n...       sexist
# 6744                                that is what we do        sexist
# 6745  never forget it is always the mans fault never...       sexist
# 6746  it is the guys who love these instagram sluts ...       sexist
# 6747  complexes like the good chicks that go after t...       sexist
#
#                                 label_category  \
# 0                                2. derogation
# 1                                2. derogation
# 2                                2. derogation
# 3     1. threats, plans to harm and incitement
# 4                                 3. animosity
# ...                                        ...
# 6743                             2. derogation
# 6744                              3. animosity
# 6745                 4. prejudiced discussions
# 6746                             2. derogation
# 6747                             2. derogation
#
#                                            label_vector
# 0     2.3 dehumanising attacks & overt sexual object...
# 1                               2.1 descriptive attacks
# 2     2.3 dehumanising attacks & overt sexual object...
# 3              1.2 incitement and encouragement of harm
# 4     3.1 casual use of gendered slurs, profanities,...
# ...                                                 ...
# 6743                            2.1 descriptive attacks
# 6744  3.1 casual use of gendered slurs, profanities,...
# 6745  4.2 supporting systemic discrimination against...
# 6746                 2.2 aggressive and emotive attacks
# 6747                            2.1 descriptive attacks
#
# [6748 rows x 5 columns]

# %%
df.groupby('label_vector').describe()
# Out:
#                                                    rewire_id         \
#                                                        count unique
# label_vector
# 1.1 threats of harm                                      112     56
# 1.2 incitement and encouragement of harm                 506    254
# 2.1 descriptive attacks                                 1423    717
# 2.2 aggressive and emotive attacks                      1336    673
# 2.3 dehumanising attacks & overt sexual objecti...       395    200
# 3.1 casual use of gendered slurs, profanities, ...      1268    637
# 3.2 immutable gender differences and gender ste...       829    417
# 3.3 backhanded gendered compliments                      127     64
# 3.4 condescending explanations or unwelcome advice        93     47
# 4.1 supporting mistreatment of individual women          149     75
# 4.2 supporting systemic discrimination against ...       510    258
#
#                                                                               \
#                                                                          top
# label_vector
# 1.1 threats of harm                                  sexism2022_english-7329
# 1.2 incitement and encouragement of harm            sexism2022_english-10099
# 2.1 descriptive attacks                               sexism2022_english-760
# 2.2 aggressive and emotive attacks                   sexism2022_english-4429
# 2.3 dehumanising attacks & overt sexual objecti...  sexism2022_english-10142
# 3.1 casual use of gendered slurs, profanities, ...  sexism2022_english-10014
# 3.2 immutable gender differences and gender ste...  sexism2022_english-13237
# 3.3 backhanded gendered compliments                   sexism2022_english-362
# 3.4 condescending explanations or unwelcome advice    sexism2022_english-960
# 4.1 supporting mistreatment of individual women     sexism2022_english-16034
# 4.2 supporting systemic discrimination against ...  sexism2022_english-10606
#
#                                                          text         \
#                                                    freq count unique
# label_vector
# 1.1 threats of harm                                   2   112    111
# 1.2 incitement and encouragement of harm              2   506    501
# 2.1 descriptive attacks                               2  1423   1420
# 2.2 aggressive and emotive attacks                    2  1336   1323
# 2.3 dehumanising attacks & overt sexual objecti...    2   395    392
# 3.1 casual use of gendered slurs, profanities, ...    2  1268   1263
# 3.2 immutable gender differences and gender ste...    2   829    819
# 3.3 backhanded gendered compliments                   2   127    126
# 3.4 condescending explanations or unwelcome advice    2    93     93
# 4.1 supporting mistreatment of individual women       2   149    149
# 4.2 supporting systemic discrimination against ...    2   510    507
#
#                                                                                                        \
#                                                                                                   top
# label_vector
# 1.1 threats of harm                                           this woman needs a rope around her neck
# 1.2 incitement and encouragement of harm            we should pretend to be leftists and nonwhites...
# 2.1 descriptive attacks                             all women are inherently untrustworthy some wo...
# 2.2 aggressive and emotive attacks                  i do not understand your problem most people h...
# 2.3 dehumanising attacks & overt sexual objecti...                     sex with escortsex with a girl
# 3.1 casual use of gendered slurs, profanities, ...    yeah and when she does that she is a fake bitch
# 3.2 immutable gender differences and gender ste...  not a good look for asian women and so much fo...
# 3.3 backhanded gendered compliments                 femininity is more supportpassive so i guess i...
# 3.4 condescending explanations or unwelcome advice  dear young white girl femininity and tradition...
# 4.1 supporting mistreatment of individual women      i totally agree it is normal guy talk every m...
# 4.2 supporting systemic discrimination against ...  well i think i speak for all men when i say i ...
#
#                                                         label_sexist         \
#                                                    freq        count unique
# label_vector
# 1.1 threats of harm                                   2          112      1
# 1.2 incitement and encouragement of harm              2          506      1
# 2.1 descriptive attacks                               2         1423      1
# 2.2 aggressive and emotive attacks                    2         1336      1
# 2.3 dehumanising attacks & overt sexual objecti...    2          395      1
# 3.1 casual use of gendered slurs, profanities, ...    2         1268      1
# 3.2 immutable gender differences and gender ste...    2          829      1
# 3.3 backhanded gendered compliments                   2          127      1
# 3.4 condescending explanations or unwelcome advice    1           93      1
# 4.1 supporting mistreatment of individual women       1          149      1
# 4.2 supporting systemic discrimination against ...    2          510      1
#
#                                                                   \
#                                                        top  freq
# label_vector
# 1.1 threats of harm                                 sexist   112
# 1.2 incitement and encouragement of harm            sexist   506
# 2.1 descriptive attacks                             sexist  1423
# 2.2 aggressive and emotive attacks                  sexist  1336
# 2.3 dehumanising attacks & overt sexual objecti...  sexist   395
# 3.1 casual use of gendered slurs, profanities, ...  sexist  1268
# 3.2 immutable gender differences and gender ste...  sexist   829
# 3.3 backhanded gendered compliments                 sexist   127
# 3.4 condescending explanations or unwelcome advice  sexist    93
# 4.1 supporting mistreatment of individual women     sexist   149
# 4.2 supporting systemic discrimination against ...  sexist   510
#
#                                                    label_category         \
#                                                             count unique
# label_vector
# 1.1 threats of harm                                           112      1
# 1.2 incitement and encouragement of harm                      506      1
# 2.1 descriptive attacks                                      1423      1
# 2.2 aggressive and emotive attacks                           1336      1
# 2.3 dehumanising attacks & overt sexual objecti...            395      1
# 3.1 casual use of gendered slurs, profanities, ...           1268      1
# 3.2 immutable gender differences and gender ste...            829      1
# 3.3 backhanded gendered compliments                           127      1
# 3.4 condescending explanations or unwelcome advice             93      1
# 4.1 supporting mistreatment of individual women               149      1
# 4.2 supporting systemic discrimination against ...            510      1
#
#                                                                                               \
#                                                                                          top
# label_vector
# 1.1 threats of harm                                 1. threats, plans to harm and incitement
# 1.2 incitement and encouragement of harm            1. threats, plans to harm and incitement
# 2.1 descriptive attacks                                                        2. derogation
# 2.2 aggressive and emotive attacks                                             2. derogation
# 2.3 dehumanising attacks & overt sexual objecti...                             2. derogation
# 3.1 casual use of gendered slurs, profanities, ...                              3. animosity
# 3.2 immutable gender differences and gender ste...                              3. animosity
# 3.3 backhanded gendered compliments                                             3. animosity
# 3.4 condescending explanations or unwelcome advice                              3. animosity
# 4.1 supporting mistreatment of individual women                    4. prejudiced discussions
# 4.2 supporting systemic discrimination against ...                 4. prejudiced discussions
#
#
#                                                     freq
# label_vector
# 1.1 threats of harm                                  112
# 1.2 incitement and encouragement of harm             506
# 2.1 descriptive attacks                             1423
# 2.2 aggressive and emotive attacks                  1336
# 2.3 dehumanising attacks & overt sexual objecti...   395
# 3.1 casual use of gendered slurs, profanities, ...  1268
# 3.2 immutable gender differences and gender ste...   829
# 3.3 backhanded gendered compliments                  127
# 3.4 condescending explanations or unwelcome advice    93
# 4.1 supporting mistreatment of individual women      149
# 4.2 supporting systemic discrimination against ...   510

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
X = df.text
tfid_vec = TfidfVectorizer().fit(X)
X_corpus =  tfid_vec.transform(X)

# %%
X_corpus.shape
# Out:
# (6748, 10856)

# %%
X = df.text
y = df.label_vector
label_encoder = LabelEncoder().fit(y)
encoded_y = label_encoder.transform(y)

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 6), dpi=80)
sns.countplot(x = df.label_vector)
plt.xlabel('label')
# Out:
# Text(0.5, 0, 'label')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import f1_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X_corpus, encoded_y , random_state =42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5061, 10856)
# (1687, 10856)

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression

# %%
l_model = LogisticRegression()
l_model.fit(X_train, y_train)
l_sentiment_yhat = l_model.predict(X_test)
l_sentiment_accuracy = accuracy_score(y_true = y_test, y_pred = l_sentiment_yhat)
l_sentiment_f1 = f1_score(y_true = y_test, y_pred =l_sentiment_yhat, average = 'weighted')
# Out:
# c:\Users\mufdu\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(f"The accuracy from logistic sentiment classification: {l_sentiment_accuracy}")
print(f"with f1 score: {l_sentiment_f1}")
print(classification_report(y_true = y_test, y_pred = l_sentiment_yhat ))
# Out:
# The accuracy from logistic sentiment classification: 0.5228215767634855
# with f1 score: 0.4840854215248488
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        26
#            1       0.68      0.44      0.53       124
#            2       0.47      0.78      0.59       361
#            3       0.51      0.61      0.56       342
#            4       0.89      0.08      0.15        95
#            5       0.53      0.68      0.59       311
#            6       0.57      0.42      0.48       208
#            7       0.00      0.00      0.00        27
#            8       0.00      0.00      0.00        23
#            9       0.00      0.00      0.00        44
#           10       0.79      0.26      0.39       126
#
#     accuracy                           0.52      1687
#    macro avg       0.40      0.30      0.30      1687
# weighted avg       0.53      0.52      0.48      1687
# c:\Users\mufdu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mufdu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mufdu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
sns.heatmap(confusion_matrix(y_true= y_test, y_pred = l_sentiment_yhat) / len(l_sentiment_yhat), 
            annot = True, cmap ='coolwarm')
plt.title('Sentiment classification')
# Out:
# Text(0.5, 1.0, 'Sentiment classification')

# %% [markdown]
# **Support Vector Classification SVC**

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()
svm_model.fit(X_train, y_train)
svm_topic_yhat = svm_model.predict(X_test)
svm_topic_accuracy = accuracy_score(y_true = y_test, y_pred = svm_topic_yhat )
svm_topic_f1 = f1_score(y_true = y_test, y_pred = svm_topic_yhat, average = 'weighted')

# %%
print(f"The accuracy from SVM sentiment classification: {svm_topic_accuracy}")
print(f"with f1 score: {svm_topic_f1}")
print(classification_report(y_true = y_test, y_pred = svm_topic_yhat ))
# Out:
# The accuracy from SVM sentiment classification: 0.6188500296384114
# with f1 score: 0.5864283437540347
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        26
#            1       0.84      0.52      0.65       124
#            2       0.52      0.85      0.65       361
#            3       0.58      0.75      0.65       342
#            4       1.00      0.15      0.26        95
#            5       0.65      0.75      0.70       311
#            6       0.76      0.54      0.63       208
#            7       1.00      0.04      0.07        27
#            8       0.00      0.00      0.00        23
#            9       1.00      0.05      0.09        44
#           10       0.98      0.42      0.59       126
#
#     accuracy                           0.62      1687
#    macro avg       0.67      0.37      0.39      1687
# weighted avg       0.68      0.62      0.59      1687
# c:\Users\mufdu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mufdu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\mufdu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
sns.heatmap(confusion_matrix(y_true= y_test, y_pred = svm_topic_yhat) / len(svm_topic_yhat), 
            annot = True, cmap ='coolwarm')
plt.title('Sentiment classification')
# Out:
# Text(0.5, 1.0, 'Sentiment classification')

# %% [markdown]
# **RANDOM FOREST CLASSIFIER**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_topic_yhat = rf_model.predict(X_test)
rf_topic_accuracy = accuracy_score(y_true = y_test, y_pred = rf_topic_yhat )
rf_topic_f1 = f1_score(y_true = y_test, y_pred = rf_topic_yhat, average = 'weighted')

# %%
print(f"The accuracy from SVM sentiment classification: {rf_topic_accuracy}")
print(f"with f1 score: {rf_topic_f1}")
print(classification_report(y_true = y_test, y_pred = rf_topic_yhat ))
# Out:
# The accuracy from SVM sentiment classification: 0.6870183758150563
# with f1 score: 0.6851956094290558
#               precision    recall  f1-score   support
#
#            0       1.00      0.38      0.56        26
#            1       0.86      0.67      0.75       124
#            2       0.55      0.85      0.67       361
#            3       0.66      0.67      0.67       342
#            4       0.96      0.47      0.63        95
#            5       0.66      0.80      0.72       311
#            6       0.87      0.63      0.74       208
#            7       1.00      0.52      0.68        27
#            8       1.00      0.52      0.69        23
#            9       1.00      0.36      0.53        44
#           10       1.00      0.48      0.65       126
#
#     accuracy                           0.69      1687
#    macro avg       0.87      0.58      0.66      1687
# weighted avg       0.74      0.69      0.69      1687

# %%
sns.heatmap(confusion_matrix(y_true= y_test, y_pred = rf_topic_yhat) / len(rf_topic_yhat), 
            annot = True, cmap ='coolwarm')
plt.title('Sentiment classification')
# Out:
# Text(0.5, 1.0, 'Sentiment classification')
